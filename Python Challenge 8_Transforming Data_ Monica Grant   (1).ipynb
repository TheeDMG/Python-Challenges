# %% [markdown]
# ## Transforming Data Challenge

# %%
import pandas as pd

# %%
df=pd.read_excel('Northwind_products_suppliers.xlsx')

# %%
df
# Out:
#     product_id                      product_name    quantity_per_unit  \
# 0            1                              Chai   10 boxes x 30 bags
# 1            2                             Chang   24 - 12 oz bottles
# 2            2                             Chang   24 - 12 oz bottles
# 3            3                     Aniseed Syrup  12 - 550 ml bottles
# 4            4      Chef Anton's Cajun Seasoning       48 - 6 oz jars
# ..         ...                               ...                  ...
# 73          63                      Vegie-spread      15 - 625 g jars
# 74          64        Wimmers gute Semmelkn√∂del   20 bags x 4 pieces
# 75          65  Louisiana Fiery Hot Pepper Sauce    32 - 8 oz bottles
# 76          66         Louisiana Hot Spiced Okra       24 - 8 oz jars
# 77          69                  Gudbrandsdalsost           10 kg pkg.
#
#     unit_price  units_in_stock  units_on_order  reorder_level  discontinued  \
# 0        18.00              39               0           10.0             1
# 1        19.00              17              40           25.0             1
# 2        19.00              17              40           25.0             1
# 3        10.00              13              70           25.0             0
# 4        22.00              53               0            0.0             0
# ..         ...             ...             ...            ...           ...
# 73       43.90              24               0            5.0             0
# 74       33.25              22              80           30.0             0
# 75       21.05              76               0            0.0             0
# 76       17.00               4             100           20.0             0
# 77       36.00              26               0           15.0             0
#
#      category_name                         company_name    country website
# 0        Beverages             Specialty Biscuits, Ltd.         UK       /
# 1        Beverages                       Exotic Liquids         UK     NaN
# 2        Beverages                       Exotic Liquids         UK     NaN
# 3       Condiments                       Exotic Liquids         UK      ""
# 4       Condiments           New Orleans Cajun Delights        USA     NaN
# ..             ...                                  ...        ...     ...
# 73      Condiments                        Pavlova, Ltd.  Australia     NaN
# 74  Grains/Cereals  Plutzer Lebensmittelgro√üm√§rkte AG    Germany     NaN
# 75      Condiments           New Orleans Cajun Delights        USA     NaN
# 76      Condiments           New Orleans Cajun Delights        USA     NaN
# 77  Dairy Products                      Norske Meierier     Norway     NaN
#
# [78 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         78 non-null     int64
#  1   product_name       78 non-null     object
#  2   quantity_per_unit  78 non-null     object
#  3   unit_price         78 non-null     float64
#  4   units_in_stock     78 non-null     int64
#  5   units_on_order     78 non-null     int64
#  6   reorder_level      76 non-null     float64
#  7   discontinued       78 non-null     int64
#  8   category_name      78 non-null     object
#  9   company_name       78 non-null     object
#  10  country            78 non-null     object
#  11  website            6 non-null      object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 7.4+ KB

# %%
df.describe()
# Out:
#        product_id  unit_price  units_in_stock  units_on_order  reorder_level  \
# count   78.000000   78.000000       78.000000       78.000000      76.000000
# mean    38.525641   28.707821       40.205128       10.512821      12.631579
# std     22.617499   33.627362       36.010229       23.237757      10.907908
# min      1.000000    2.500000        0.000000        0.000000       0.000000
# 25%     19.250000   13.062500       15.000000        0.000000       0.000000
# 50%     38.500000   19.475000       26.000000        0.000000      12.500000
# 75%     57.750000   33.137500       60.000000        0.000000      25.000000
# max     77.000000  263.500000      125.000000      100.000000      30.000000
#
#        discontinued
# count     78.000000
# mean       0.141026
# std        0.350301
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# ## 1. What data is in the first 4 rows?

# %%
df.head(4)
# Out:
#    product_id   product_name    quantity_per_unit  unit_price  units_in_stock  \
# 0           1           Chai   10 boxes x 30 bags        18.0              39
# 1           2          Chang   24 - 12 oz bottles        19.0              17
# 2           2          Chang   24 - 12 oz bottles        19.0              17
# 3           3  Aniseed Syrup  12 - 550 ml bottles        10.0              13
#
#    units_on_order  reorder_level  discontinued category_name  \
# 0               0           10.0             1     Beverages
# 1              40           25.0             1     Beverages
# 2              40           25.0             1     Beverages
# 3              70           25.0             0    Condiments
#
#                company_name country website
# 0  Specialty Biscuits, Ltd.      UK       /
# 1            Exotic Liquids      UK     NaN
# 2            Exotic Liquids      UK     NaN
# 3            Exotic Liquids      UK      ""

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'quantity_per_unit', 'unit_price',
#        'units_in_stock', 'units_on_order', 'reorder_level', 'discontinued',
#        'category_name', 'company_name', 'country', 'website'],
#       dtype='object')

# %% [markdown]
# ## 2. Calculate how many rows and columns are in this file.

# %%
df.shape
# Out:
# (78, 12)

# %% [markdown]
# ## 3. What’s the maximum unit_price?

# %%
df['unit_price'].max ()
# Out:
# 263.5

# %% [markdown]
# ## 4. Use describe() to get the descriptive statistics for this file

# %%
df.describe()
# Out:
#        product_id  unit_price  units_in_stock  units_on_order  reorder_level  \
# count   78.000000   78.000000       78.000000       78.000000      76.000000
# mean    38.525641   28.707821       40.205128       10.512821      12.631579
# std     22.617499   33.627362       36.010229       23.237757      10.907908
# min      1.000000    2.500000        0.000000        0.000000       0.000000
# 25%     19.250000   13.062500       15.000000        0.000000       0.000000
# 50%     38.500000   19.475000       26.000000        0.000000      12.500000
# 75%     57.750000   33.137500       60.000000        0.000000      25.000000
# max     77.000000  263.500000      125.000000      100.000000      30.000000
#
#        discontinued
# count     78.000000
# mean       0.141026
# std        0.350301
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# ## 5. Replace any NULL values in reorder_level with 0

# %%
df.isnull().sum()
# Out:
# product_id            0
# product_name          0
# quantity_per_unit     0
# unit_price            0
# units_in_stock        0
# units_on_order        0
# reorder_level         2
# discontinued          0
# category_name         0
# company_name          0
# country               0
# website              72
# dtype: int64

# %%
df['reorder_level']=df['reorder_level'].fillna(0)

# %%
df.isnull().sum()
# Out:
# product_id            0
# product_name          0
# quantity_per_unit     0
# unit_price            0
# units_in_stock        0
# units_on_order        0
# reorder_level         0
# discontinued          0
# category_name         0
# company_name          0
# country               0
# website              72
# dtype: int64

# %%
df.describe()
# Out:
#        product_id  unit_price  units_in_stock  units_on_order  reorder_level  \
# count   78.000000   78.000000       78.000000       78.000000      78.000000
# mean    38.525641   28.707821       40.205128       10.512821      12.307692
# std     22.617499   33.627362       36.010229       23.237757      10.951259
# min      1.000000    2.500000        0.000000        0.000000       0.000000
# 25%     19.250000   13.062500       15.000000        0.000000       0.000000
# 50%     38.500000   19.475000       26.000000        0.000000      10.000000
# 75%     57.750000   33.137500       60.000000        0.000000      23.750000
# max     77.000000  263.500000      125.000000      100.000000      30.000000
#
#        discontinued
# count     78.000000
# mean       0.141026
# std        0.350301
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.loc[df['reorder_level']==0]
# Out:
#     product_id                      product_name     quantity_per_unit  \
# 4            4      Chef Anton's Cajun Seasoning        48 - 6 oz jars
# 5            5            Chef Anton's Gumbo Mix              36 boxes
# 6            6      Grandma's Boysenberry Spread        12 - 8 oz jars
# 8            8        Northwoods Cranberry Sauce       12 - 12 oz jars
# 10           9                   Mishi Kobe Niku      18 - 500 g pkgs.
# 11          10                             Ikura      12 - 200 ml jars
# 13          12         Queso Manchego La Pastora      10 - 500 g pkgs.
# 14          14                              Tofu      40 - 100 g pkgs.
# 18          46                         Spegesild     4 - 450 g glasses
# 19          47                     Zaanse koeken       10 - 4 oz boxes
# 24          71                       Flotemysost      10 - 500 g pkgs.
# 25          72            Mozzarella di Giovanni      24 - 200 g pkgs.
# 32          17                      Alice Mutton        20 - 1 kg tins
# 33          18                  Carnarvon Tigers            16 kg pkg.
# 35          20            Sir Rodney's Marmalade         30 gift boxes
# 39          24              Guaran√° Fant√°stica      12 - 355 ml cans
# 41          26             Gumb√§r Gummib√§rchen      100 - 250 g bags
# 43          28                R√∂ssle Sauerkraut       25 - 825 g cans
# 44          29          Th√ºringer Rostbratwurst  50 bags x 30 sausgs.
# 56          42     Singaporean Hokkien Fried Mee       32 - 1 kg pkgs.
# 63          53                     Perth Pasties             48 pieces
# 69          59              Raclette Courdavault             5 kg pkg.
# 70          60                 Camembert Pierrot     15 - 300 g rounds
# 72          62                    Tarte au sucre               48 pies
# 75          65  Louisiana Fiery Hot Pepper Sauce     32 - 8 oz bottles
#
#     unit_price  units_in_stock  units_on_order  reorder_level  discontinued  \
# 4        22.00              53               0            0.0             0
# 5        21.35               0               0            0.0             1
# 6        25.00             120               0            0.0             0
# 8        40.00               6               0            0.0             0
# 10       97.00              29               0            0.0             1
# 11       31.00              31               0            0.0             0
# 13       38.00              86               0            0.0             0
# 14       23.25              35               0            0.0             0
# 18       12.00              95               0            0.0             0
# 19        9.50              36               0            0.0             0
# 24       21.50              26               0            0.0             0
# 25       34.80              14               0            0.0             0
# 32       39.00               0               0            0.0             1
# 33       62.50              42               0            0.0             0
# 35       81.00              40               0            0.0             0
# 39        4.50              20               0            0.0             1
# 41       31.23              15               0            0.0             0
# 43       45.60              26               0            0.0             1
# 44      123.79               0               0            0.0             1
# 56       14.00              26               0            0.0             1
# 63       32.80               0               0            0.0             1
# 69       55.00              79               0            0.0             0
# 70       34.00              19               0            0.0             0
# 72       49.30              17               0            0.0             0
# 75       21.05              76               0            0.0             0
#
#      category_name                         company_name      country website
# 4       Condiments           New Orleans Cajun Delights          USA     NaN
# 5       Condiments           New Orleans Cajun Delights          USA     NaN
# 6       Condiments            Grandma Kelly's Homestead          USA     2ww
# 8       Condiments            Grandma Kelly's Homestead          USA     NaN
# 10    Meat/Poultry                        Tokyo Traders        Japan     NaN
# 11         Seafood                        Tokyo Traders        Japan     NaN
# 13  Dairy Products   Cooperativa de Quesos 'Las Cabras'        Spain       f
# 14         Produce                             Mayumi's        Japan     NaN
# 18         Seafood                           Lyngbysild      Denmark     NaN
# 19     Confections                  Zaanse Snoepfabriek  Netherlands     NaN
# 24  Dairy Products                      Norske Meierier       Norway       W
# 25  Dairy Products              Formaggi Fortini s.r.l.        Italy     NaN
# 32    Meat/Poultry                        Pavlova, Ltd.    Australia     NaN
# 33         Seafood                        Pavlova, Ltd.    Australia     NaN
# 35     Confections             Specialty Biscuits, Ltd.           UK     NaN
# 39       Beverages            Refrescos Americanas LTDA       Brazil     NaN
# 41     Confections        Heli S√º√üwaren GmbH & Co. KG      Germany     NaN
# 43         Produce  Plutzer Lebensmittelgro√üm√§rkte AG      Germany     NaN
# 44    Meat/Poultry  Plutzer Lebensmittelgro√üm√§rkte AG      Germany     NaN
# 56  Grains/Cereals                         Leka Trading    Singapore     NaN
# 63    Meat/Poultry                          G'day, Mate    Australia     NaN
# 69  Dairy Products                        Gai p√¢turage       France     NaN
# 70  Dairy Products                        Gai p√¢turage       France     NaN
# 72     Confections                   For√™ts d'√©rables       Canada     NaN
# 75      Condiments           New Orleans Cajun Delights          USA     NaN

# %%
df
# Out:
#     product_id                      product_name    quantity_per_unit  \
# 0            1                              Chai   10 boxes x 30 bags
# 1            2                             Chang   24 - 12 oz bottles
# 2            2                             Chang   24 - 12 oz bottles
# 3            3                     Aniseed Syrup  12 - 550 ml bottles
# 4            4      Chef Anton's Cajun Seasoning       48 - 6 oz jars
# ..         ...                               ...                  ...
# 73          63                      Vegie-spread      15 - 625 g jars
# 74          64        Wimmers gute Semmelkn√∂del   20 bags x 4 pieces
# 75          65  Louisiana Fiery Hot Pepper Sauce    32 - 8 oz bottles
# 76          66         Louisiana Hot Spiced Okra       24 - 8 oz jars
# 77          69                  Gudbrandsdalsost           10 kg pkg.
#
#     unit_price  units_in_stock  units_on_order  reorder_level  discontinued  \
# 0        18.00              39               0           10.0             1
# 1        19.00              17              40           25.0             1
# 2        19.00              17              40           25.0             1
# 3        10.00              13              70           25.0             0
# 4        22.00              53               0            0.0             0
# ..         ...             ...             ...            ...           ...
# 73       43.90              24               0            5.0             0
# 74       33.25              22              80           30.0             0
# 75       21.05              76               0            0.0             0
# 76       17.00               4             100           20.0             0
# 77       36.00              26               0           15.0             0
#
#      category_name                         company_name    country website
# 0        Beverages             Specialty Biscuits, Ltd.         UK       /
# 1        Beverages                       Exotic Liquids         UK     NaN
# 2        Beverages                       Exotic Liquids         UK     NaN
# 3       Condiments                       Exotic Liquids         UK      ""
# 4       Condiments           New Orleans Cajun Delights        USA     NaN
# ..             ...                                  ...        ...     ...
# 73      Condiments                        Pavlova, Ltd.  Australia     NaN
# 74  Grains/Cereals  Plutzer Lebensmittelgro√üm√§rkte AG    Germany     NaN
# 75      Condiments           New Orleans Cajun Delights        USA     NaN
# 76      Condiments           New Orleans Cajun Delights        USA     NaN
# 77  Dairy Products                      Norske Meierier     Norway     NaN
#
# [78 rows x 12 columns]

# %% [markdown]
# ## 6.Remove duplicate rows

# %%
df.duplicated().sum() #find the duplicates
# Out:
# 1

# %%
df_nodupes = df.drop_duplicates() #gets rid of the duplicate rows

# %%
df_nodupes.duplicated().sum() #recheck dupes
# Out:
# 0

# %% [markdown]
# ## 7. Change "Gustaf's Kn√§ckebr√∂d" To "Gustaf's Knäckebröd"

# %%
fixed_df = df.replace("Gustaf's Kn√§ckebr√∂d","Gustaf's Knäckebröd", regex=True) #make corrections

# %% [markdown]
# ## 8. Remove the column for website

# %%
df.drop(columns=['website'])
# Out:
#     product_id                      product_name    quantity_per_unit  \
# 0            1                              Chai   10 boxes x 30 bags
# 1            2                             Chang   24 - 12 oz bottles
# 2            2                             Chang   24 - 12 oz bottles
# 3            3                     Aniseed Syrup  12 - 550 ml bottles
# 4            4      Chef Anton's Cajun Seasoning       48 - 6 oz jars
# ..         ...                               ...                  ...
# 73          63                      Vegie-spread      15 - 625 g jars
# 74          64        Wimmers gute Semmelkn√∂del   20 bags x 4 pieces
# 75          65  Louisiana Fiery Hot Pepper Sauce    32 - 8 oz bottles
# 76          66         Louisiana Hot Spiced Okra       24 - 8 oz jars
# 77          69                  Gudbrandsdalsost           10 kg pkg.
#
#     unit_price  units_in_stock  units_on_order  reorder_level  discontinued  \
# 0        18.00              39               0           10.0             1
# 1        19.00              17              40           25.0             1
# 2        19.00              17              40           25.0             1
# 3        10.00              13              70           25.0             0
# 4        22.00              53               0            0.0             0
# ..         ...             ...             ...            ...           ...
# 73       43.90              24               0            5.0             0
# 74       33.25              22              80           30.0             0
# 75       21.05              76               0            0.0             0
# 76       17.00               4             100           20.0             0
# 77       36.00              26               0           15.0             0
#
#      category_name                         company_name    country
# 0        Beverages             Specialty Biscuits, Ltd.         UK
# 1        Beverages                       Exotic Liquids         UK
# 2        Beverages                       Exotic Liquids         UK
# 3       Condiments                       Exotic Liquids         UK
# 4       Condiments           New Orleans Cajun Delights        USA
# ..             ...                                  ...        ...
# 73      Condiments                        Pavlova, Ltd.  Australia
# 74  Grains/Cereals  Plutzer Lebensmittelgro√üm√§rkte AG    Germany
# 75      Condiments           New Orleans Cajun Delights        USA
# 76      Condiments           New Orleans Cajun Delights        USA
# 77  Dairy Products                      Norske Meierier     Norway
#
# [78 rows x 11 columns]

# %% [markdown]
# ## 9. Create a crosstab, with category_name in rows and country in columns

# %%
crosstab=pd.crosstab(df['category_name'], df['country'])  # count

# %%
crosstab
# Out:
# country         Australia  Brazil  Canada  Denmark  Finland  France  Germany  \
# category_name
# Beverages               1       1       0        0        1       2        1
# Condiments              1       0       1        0        0       0        1
# Confections             1       0       1        0        2       0        3
# Dairy Products          0       0       0        0        0       2        0
# Grains/Cereals          1       0       0        0        0       0        1
# Meat/Poultry            2       0       2        0        0       0        1
# Produce                 1       0       0        0        0       0        1
# Seafood                 1       0       0        2        0       1        1
#
# country         Italy  Japan  Netherlands  Norway  Singapore  Spain  Sweden  \
# category_name
# Beverages           0      0            0       0          1      0       0
# Condiments          0      1            0       0          1      0       0
# Confections         0      0            2       0          0      0       0
# Dairy Products      3      0            0       3          0      2       0
# Grains/Cereals      2      0            0       0          1      0       2
# Meat/Poultry        0      1            0       0          0      0       0
# Produce             0      2            0       0          0      0       0
# Seafood             0      2            0       0          0      0       3
#
# country         UK  USA
# category_name
# Beverages        3    3
# Condiments       1    6
# Confections      4    0
# Dairy Products   0    0
# Grains/Cereals   0    0
# Meat/Poultry     0    0
# Produce          0    1
# Seafood          0    2

# %% [markdown]
# ## 10. Create a pivot table with average unit_price by category

# %%
# pivot_df = df.pivot_table('what to aggregate', index='what to put in rows',  aggfunc='avg')  
# df.pivot_table(['category_name'],index=['unit_price'], aggfunc='mean')
df.pivot_table(index=['category_name'], values=['unit_price'], aggfunc='mean')
# Out:
#                 unit_price
# category_name
# Beverages        36.519231
# Condiments       22.854167
# Confections      25.160000
# Dairy Products   28.730000
# Grains/Cereals   20.250000
# Meat/Poultry     54.006667
# Produce          32.370000
# Seafood          20.682500

# %% [markdown]
# ## 11. Create a pivot table with average reorder_level  by category (rows) and country (columns

# %%
df.pivot_table(index=['country'], values=['reorder_level'], aggfunc='mean')
# Out:
#              reorder_level
# country
# Australia        10.000000
# Brazil            0.000000
# Canada           13.750000
# Denmark           7.500000
# Finland          21.666667
# France            8.000000
# Germany          16.111111
# Italy            19.000000
# Japan             2.500000
# Netherlands      12.500000
# Norway           11.666667
# Singapore        13.333333
# Spain            15.000000
# Sweden           20.000000
# UK               13.750000
# USA               9.166667

# %% [markdown]
# ## 12. Create a groupby table with sum of discontinued products by company name

# %%
# df_grouped = df.groupby(['rows1','row2'])['columns'].mean()
df_grouped = df.groupby(['company_name'])['discontinued'].sum()

# %%
df_grouped
# Out:
# company_name
# Aux joyeux eccl√©siastiques               0
# Bigfoot Breweries                         0
# Cooperativa de Quesos 'Las Cabras'        0
# Escargots Nouveaux                        0
# Exotic Liquids                            2
# Formaggi Fortini s.r.l.                   0
# For√™ts d'√©rables                        0
# G'day, Mate                               1
# Gai p√¢turage                             0
# Grandma Kelly's Homestead                 0
# Heli S√º√üwaren GmbH & Co. KG             0
# Karkki Oy                                 0
# Leka Trading                              1
# Lyngbysild                                0
# Ma Maison                                 0
# Mayumi's                                  0
# New England Seafood Cannery               0
# New Orleans Cajun Delights                1
# Nord-Ost-Fisch Handelsgesellschaft mbH    0
# Norske Meierier                           0
# PB Kn√§ckebr√∂d AB                        0
# Pasta Buttini s.r.l.                      0
# Pavlova, Ltd.                             1
# Plutzer Lebensmittelgro√üm√§rkte AG       2
# Refrescos Americanas LTDA                 1
# Specialty Biscuits, Ltd.                  1
# Svensk Sj√∂f√∂da AB                       0
# Tokyo Traders                             1
# Zaanse Snoepfabriek                       0
# Name: discontinued, dtype: int64

# %% [markdown]
# ## 13. Create a groupby table with maximum unit_price by country and category (both in rows

# %%
# df_grouped = df.groupby(['rows1','row2'])['columns'].mean()
df_grouped_2 = df.groupby(['country','category_name'])['unit_price'].max()

# %%
df_grouped_2
# Out:
# country      category_name
# Australia    Beverages          15.00
#              Condiments         43.90
#              Confections        17.45
#              Grains/Cereals      7.00
#              Meat/Poultry       39.00
#              Produce            53.00
#              Seafood            62.50
# Brazil       Beverages           4.50
# Canada       Condiments         28.50
#              Confections        49.30
#              Meat/Poultry       24.00
# Denmark      Seafood            12.00
# Finland      Beverages          18.00
#              Confections        20.00
# France       Beverages         263.50
#              Dairy Products     55.00
#              Seafood            13.25
# Germany      Beverages           7.75
#              Condiments         13.00
#              Confections        43.90
#              Grains/Cereals     33.25
#              Meat/Poultry      123.79
#              Produce            45.60
#              Seafood            25.89
# Italy        Dairy Products     34.80
#              Grains/Cereals     38.00
# Japan        Condiments         13.00
#              Meat/Poultry       97.00
#              Produce            23.25
#              Seafood            31.00
# Netherlands  Confections        12.75
# Norway       Dairy Products     36.00
# Singapore    Beverages          46.00
#              Condiments         19.45
#              Grains/Cereals     14.00
# Spain        Dairy Products     38.00
# Sweden       Grains/Cereals     21.00
#              Seafood            26.00
# UK           Beverages          19.00
#              Condiments         10.00
#              Confections        81.00
# USA          Beverages          18.00
#              Condiments         40.00
#              Produce            30.00
#              Seafood            18.40
# Name: unit_price, dtype: float64
