# %% [markdown]
# ## Python Challenge 9 _ Visuals

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('countries_clean.csv')

# %%
df
# Out:
#      Unnamed: 0          Country                               Region  \
# 0             0     Afghanistan         Asia (Ex. Near East)
# 1             1         Albania   Eastern Europe
# 2             2         Algeria   Northern Africa
# 3             3  American Samoa   Oceania
# 4             4         Andorra   Western Europe
# ..          ...              ...                                  ...
# 222         222       West Bank   Near East
# 223         223  Western Sahara   Northern Africa
# 224         224           Yemen   Near East
# 225         225          Zambia   Sub-Saharan Africa
# 226         226        Zimbabwe   Sub-Saharan Africa
#
#      Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      31056997          647500                        48.0
# 1       3581655           28748                       124.6
# 2      32930091         2381740                        13.8
# 3         57794             199                       290.4
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Birthrate',
#        'Deathrate'],
#       dtype='object')

# %%
df.shape
# Out:
# (227, 14)

# %% [markdown]
# ## 1. Population by Country Line Chart

# %%
df_country_by_population = df[['Country', 'Population']]

# %%
df_country_by_population
# Out:
#              Country  Population
# 0       Afghanistan     31056997
# 1           Albania      3581655
# 2           Algeria     32930091
# 3    American Samoa        57794
# 4           Andorra        71201
# ..               ...         ...
# 222       West Bank      2460492
# 223  Western Sahara       273008
# 224           Yemen     21456188
# 225          Zambia     11502010
# 226        Zimbabwe     12236805
#
# [227 rows x 2 columns]

# %%
df_country_by_population.head(5) #first 5 countries in alpha-order
# Out:
#            Country  Population
# 0     Afghanistan     31056997
# 1         Albania      3581655
# 2         Algeria     32930091
# 3  American Samoa        57794
# 4         Andorra        71201

# %%
plt.figure(figsize=(10,3)) 
plt.plot(df_country_by_population.head(5)['Country'], df_country_by_population.head(5)['Population'], color='c', marker='D')
plt.xlabel('Country (First 5)')
plt.ylabel('Population (Millions)')
plt.title('Population by Country by Monica Grant')
plt.show()

# %% [markdown]
# ## 2. GDP by Country Bar Chart

# %%
df
# Out:
#      Unnamed: 0          Country                               Region  \
# 0             0     Afghanistan         Asia (Ex. Near East)
# 1             1         Albania   Eastern Europe
# 2             2         Algeria   Northern Africa
# 3             3  American Samoa   Oceania
# 4             4         Andorra   Western Europe
# ..          ...              ...                                  ...
# 222         222       West Bank   Near East
# 223         223  Western Sahara   Northern Africa
# 224         224           Yemen   Near East
# 225         225          Zambia   Sub-Saharan Africa
# 226         226        Zimbabwe   Sub-Saharan Africa
#
#      Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      31056997          647500                        48.0
# 1       3581655           28748                       124.6
# 2      32930091         2381740                        13.8
# 3         57794             199                       290.4
# ...

# %%
df
# Out:
#      Unnamed: 0          Country                               Region  \
# 0             0     Afghanistan         Asia (Ex. Near East)
# 1             1         Albania   Eastern Europe
# 2             2         Algeria   Northern Africa
# 3             3  American Samoa   Oceania
# 4             4         Andorra   Western Europe
# ..          ...              ...                                  ...
# 222         222       West Bank   Near East
# 223         223  Western Sahara   Northern Africa
# 224         224           Yemen   Near East
# 225         225          Zambia   Sub-Saharan Africa
# 226         226        Zimbabwe   Sub-Saharan Africa
#
#      Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      31056997          647500                        48.0
# 1       3581655           28748                       124.6
# 2      32930091         2381740                        13.8
# 3         57794             199                       290.4
# ...

# %%
df_country_gdp = df[['Country', 'GDP ($ per capita)']]

# %%
df_country_gdp.tail(10)
# Out:
#                 Country  GDP ($ per capita)
# 217            Vanuatu               2900.0
# 218          Venezuela               4800.0
# 219            Vietnam               2500.0
# 220     Virgin Islands              17200.0
# 221  Wallis and Futuna               3700.0
# 222          West Bank                800.0
# 223     Western Sahara                  0.0
# 224              Yemen                800.0
# 225             Zambia                800.0
# 226           Zimbabwe               1900.0

# %%
plt.figure(figsize=(10,3))
plt.bar(df_country_gdp.tail(5)['Country'], df_country_gdp.tail(5)['GDP ($ per capita)'], color='m')
plt.xlabel('Last 5 Countries')
plt.ylabel('GDP  ($ per capita)')
plt.title('GDP by Country Bar Chart by Monica Grant')
plt.show()

# %% [markdown]
# ## 3. Deathrate per Region Bar Chart

# %%
df
# Out:
#      Unnamed: 0          Country                               Region  \
# 0             0     Afghanistan         Asia (Ex. Near East)
# 1             1         Albania   Eastern Europe
# 2             2         Algeria   Northern Africa
# 3             3  American Samoa   Oceania
# 4             4         Andorra   Western Europe
# ..          ...              ...                                  ...
# 222         222       West Bank   Near East
# 223         223  Western Sahara   Northern Africa
# 224         224           Yemen   Near East
# 225         225          Zambia   Sub-Saharan Africa
# 226         226        Zimbabwe   Sub-Saharan Africa
#
#      Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      31056997          647500                        48.0
# 1       3581655           28748                       124.6
# 2      32930091         2381740                        13.8
# 3         57794             199                       290.4
# ...

# %%
# df_country_area = df[['Country', 'Area (sq. mi.)']]

# %%
# df_country_area[20:30]

# %%
df_region_deathrate = df[['Region', 'Deathrate']]

# %%
df_region_deathrate.head(5)
# Out:
#                                 Region  Deathrate
# 0        Asia (Ex. Near East)               20.34
# 1  Eastern Europe                            5.22
# 2  Northern Africa                           4.61
# 3  Oceania                                   3.27
# 4  Western Europe                            6.25

# %%
plt.figure(figsize=(15,3))
plt.bar(df_region_deathrate.head(5)['Region'] ,df_region_deathrate.head(5)['Deathrate'] , color='orange', width=.75) 
plt.xlabel('Region')
plt.ylabel('Deathrate')
plt.title('Deathrate per Region by Monica Grant')
plt.show()
